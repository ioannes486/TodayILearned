# %% [markdown]
# 우리가 배운 코드는 정점이 중복되게 삽입된다.
#
# ![image.png](attachment:image.png)
#
#
# 피보나치 입을 쓰면 훨씬 빨라진다
# 2단계의 레벨업을 해야 프림 알고리즘이 완성된다.
#
# 밀집그래프 -> 간선이 많을 수록 유리해야 한다.

# %%
프림을 할 겨면 간선의 정보를 미리 넣을 필요가 있나?
크루스칼은 간선의 정보를 미리 넣어야 한다.
